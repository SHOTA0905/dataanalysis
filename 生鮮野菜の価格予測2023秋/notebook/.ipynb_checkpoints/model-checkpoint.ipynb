# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime
import sys

import os

import matplotlib.pyplot as plt 
import japanize_matplotlib
import seaborn as sns

# %%
train = pd.read_csv('../train.csv')
test = pd.read_csv('../test.csv')
weather = pd.read_csv('../weather.csv')
alldata = pd.concat([train.copy(), test.copy()], axis = 0)

# %% [markdown]
# # データの加工

# %%
#データ件数
trainSuv = alldata[:len(train)]
testSuv = alldata[len(train):]
print(len(trainSuv), len(testSuv))
# Out:
# 69104 220

# %% [markdown]
# # データ調査

# %%
trainSuv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69104 entries, 0 to 69103
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   kind        69104 non-null  object
#  1   date        69104 non-null  int64
#  2   amount      69104 non-null  float64
#  3   mode_price  69104 non-null  float64
#  4   area        69104 non-null  object
#  5   year        69104 non-null  int64
#  6   weekno      69104 non-null  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 4.2+ MB

# %%
for clm in trainSuv.columns:
    print(
        '{}\r\nnull件数：{}, ユニークデータ数：{}'.format(
            clm, 
            trainSuv[clm].isnull().sum(), 
            len(trainSuv[clm].unique())))
# Out:
# kind
# null件数：0, ユニークデータ数：33
# date
# null件数：0, ユニークデータ数：4672
# amount
# null件数：0, ユニークデータ数：54860
# mode_price
# null件数：0, ユニークデータ数：1063
# area
# null件数：0, ユニークデータ数：217
# year
# null件数：0, ユニークデータ数：19
# weekno
# null件数：0, ユニークデータ数：53

# %%
categoryClm = ['kind', 'area']
numberClm = ['date', 'amount', 'mode_price', 'year', 'weekno']
objectVal = 'mode_price'
# jogai = [ '市区町村コード','市区町村名', '地区名', '最寄駅：名称', '種類','地域','土地の形状','間口','延床面積（㎡）',
#          '前面道路：方位','前面道路：種類','前面道路：幅員（ｍ）','Unnamed: 0', 'ID']

# for clm in trainSuv.columns:
#     if clm not in jogai:
#         if pd.api.types.is_numeric_dtype(trainSuv[clm]):
#             numberClm.append(clm)
#         if trainSuv[clm].dtype == 'object':
#             categoryClm.append(clm)

print(categoryClm)
print(numberClm)
# Out:
# ['kind', 'area']
# ['date', 'amount', 'mode_price', 'year', 'weekno']

# %%
'''
null件数確認
ユニークデータ確認
'''
'''
カテゴリ変数
    件数確認
    目的変数の箱ひげ図
    全体の中央値との差
連続変数
    ヒストグラム
    目的変数との散布図
'''
# Out:
# '\nカテゴリ変数\n    件数確認\n    目的変数の箱ひげ図\n    全体の中央値との差\n連続変数\n    ヒストグラム\n    目的変数との散布図\n'

# %%
#     fm = trainSuv[clm].value_counts()
#     plt.xticks(rotation=90)
#     plt.bar(
#         fm.index, 
#         fm.values)
import matplotlib.pyplot as plt

idx = 1
for clm in categoryClm:
    print(clm)
    #
    fm = trainSuv[clm].value_counts()
    plt.xticks(rotation=90)
    plt.rcParams["figure.figsize"] = [10,4]  
    
    plt.bar(
        fm.index, 
        fm.values)
    
    plt.show()
    
    #
    box, ax = plt.subplots()
    ax = sns.boxplot(
        x=clm, 
        y=objectVal, 
        order=trainSuv.groupby(clm)[objectVal].mean().sort_values(ascending=False).index,
        data=trainSuv
    )
    plt.xticks(rotation=90)
    plt.show()
    
    #
    fm = trainSuv.groupby(clm)[objectVal].mean()-trainSuv[objectVal].mean()

    plt.rcParams["figure.figsize"] = [10,4.0]  
    plt.xticks(rotation=90)
    plt.bar(
        fm.index, 
        fm.values)
    plt.xticks(rotation=90)
    plt.show()
# Out:
# kind
# area

# %%
# import seaborn as sns
# fig = sns.pairplot(trainSuv[numberClm])

# %%
import numpy as np
import matplotlib.pyplot as plt

idx = 1
for clm in numberClm:
    print(clm)
    #
    plt.hist(trainSuv[clm], alpha = 0.5, label='1', bins=50)

    plt.legend(loc='upper left')
    
    plt.show()
    #
    scatter_plt = plt.figure()
    ax = scatter_plt.add_subplot(1,1,1)
    ax.scatter(trainSuv[clm], trainSuv[objectVal])
    plt.show()
# Out:
# date
# amount
# mode_price
# year
# weekno

# %%
area_pairs = alldata['area'].unique()

yasai_areas = set()

for area_pair in area_pairs:
    areas = area_pair.split('_')
    yasai_areas |= set(areas)

yasai_areas

wea_areas = weather['area'].unique()
wea_areas
# Out:
# array(['青森', '盛岡', '秋田', '仙台', '山形', '福島', '水戸', '宇都宮', '前橋', '熊谷', '甲府',
#        '横浜', '千葉', '浜松', '長野', '新潟', '名古屋', '高松', '徳島', '高知', '松山', '那覇',
#        '鹿児島', '宮崎', '長崎', '熊本', '福岡', '佐賀', '和歌山', '神戸', '帯広', '東京'],
#       dtype=object)

# %%
area_map = {}

update_area_map = {
    '岩手':'盛岡','宮城':'仙台','静岡':'浜松','沖縄':'那覇','神奈川':'横浜','愛知':'名古屋','茨城':'水戸','北海道':'帯広','各地':'全国',
    '兵庫':'神戸','香川':'高松','埼玉':'熊谷','国内':'全国','山梨':'甲府','栃木':'宇都宮','群馬':'前橋','愛媛':'松山'
}

for yasai_area in yasai_areas:
    if yasai_area not in wea_areas and yasai_area not in update_area_map:
        area_map[yasai_area] = '全国' # 外国の天候は全国にしておく
    else:
        area_map[yasai_area] = yasai_area

area_map = {**area_map, **update_area_map}
area_map
# Out:
# {'青森': '青森',
#  '各地': '全国',
#  '沖縄': '那覇',
#  '北海道': '帯広',
#  '東京': '東京',
#  '新潟': '新潟',
#  '長野': '長野',
#  'カナダ': '全国',
#  '岩手': '盛岡',
#  '宮崎': '宮崎',
#  'トンガ': '全国',
#  '熊本': '熊本',
#  '福島': '福島',
#  '神奈川': '横浜',
#  '愛知': '名古屋',
#  '茨城': '水戸',
#  '福岡': '福岡',
#  '千葉': '千葉',
#  '長崎': '長崎',
#  '埼玉': '熊谷',
#  '高知': '高知',
#  '佐賀': '佐賀',
#  '香川': '高松',
#  '兵庫': '神戸',
#  '宮城': '仙台',
#  '静岡': '浜松',
#  '鹿児島': '鹿児島',
#  '徳島': '徳島',
#  '秋田': '秋田',
#  '栃木': '宇都宮',
#  'メキシコ': '全国',
#  '群馬': '前橋',
#  '愛媛': '松山',
#  '中国': '全国',
#  'ニュージーランド': '全国',
#  'アメリカ': '全国',
#  '和歌山': '和歌山',
#  '国内': '全国',
#  '山梨': '甲府'}

# %%
alldata['area_new'] = alldata['area'].apply(lambda x: '_'.join([area_map[i] for i in x.split('_')]))
alldata
# Out:
#       kind      date   amount  mode_price      area  year  weekno  area_new
# 0       かぶ  20051107  39319.0       158.0        千葉  2005      45        千葉
# 1       かぶ  20051108  35433.0       158.0        千葉  2005      45        千葉
# 2       かぶ  20051110  40208.0       126.0        千葉  2005      45        千葉
# 3       かぶ  20051111  32032.0       137.0        千葉  2005      45        千葉
# 4       かぶ  20051112  38288.0       137.0        千葉  2005      45        千葉
# ..     ...       ...      ...         ...       ...   ...     ...       ...
# 215  じゃがいも  20230725      NaN         NaN  各地_茨城_静岡  2023      30  全国_水戸_浜松
# 216  じゃがいも  20230727      NaN         NaN  各地_茨城_静岡  2023      30  全国_水戸_浜松
# 217  じゃがいも  20230728      NaN         NaN  各地_茨城_静岡  2023      30  全国_水戸_浜松
# 218  じゃがいも  20230729      NaN         NaN  各地_茨城_静岡  2023      30  全国_水戸_浜松
# 219  じゃがいも  20230731      NaN         NaN  各地_茨城_静岡  2023      31  全国_水戸_浜松
#
# [69324 rows x 8 columns]
